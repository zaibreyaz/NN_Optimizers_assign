# %% [markdown]
# ### Part 1: Understanding Optimizers

# %%
"""1. What is the role of optimization algorithms in artificial neural networks? Why are they necessary?
Ans: Choosing the right optimizer for a neural network involves tradeoffs among convergence speed, stability, and generalization performance. 
        Gradient Descent is simple but slow. Stochastic Gradient Descent (SGD) converges faster but may be unstable. 
        Adam optimizer balances speed and stability with adaptive learning rates. RMSprop is stable but might converge slower. 
The choice depends on the specific task, architecture, and data. Experimentation and tuning are essential to find the best optimizer for optimal training performance.

2. Explainthe concept of gradient descent and its variants. Discuss their differences and tradeoffs in terms of convergence speed and memory requirements.
Ans: Gradient descent is an optimization technique used in neural networks to minimize errors during training. 
        It calculates the gradient (direction of steepest ascent) and updates model weights to reach the minimum error. 
        Variants like Stochastic GD use random samples for faster convergence but higher memory, while Mini-batch GD strikes a balance by using batches of data. 
        Each variant has tradeoffs in terms of convergence speed and memory requirements.

3. Describe the challenges associated with traditional gradient descent optimization methods (e.g., slow convergence, local minima). How do modern optimizers address these challenges?
Ans: Traditional gradient descent methods suffer from slow convergence and getting stuck in local minima. Modern optimizers address these challenges by using 
        adaptive learning rates (e.g., Adam) that speed up convergence by adjusting step sizes for each parameter. 
        They also use momentum to escape local minima and converge faster towards the global minimum.

4. Discuss the concepts of momentum and learning rate int the context of optimization algorithms. How do they impact convergence and model perfromance?
Ans: In optimization algorithms, momentum is a technique that helps the optimizer move faster towards the minimum by adding a fraction of the previous gradient. 
        Learning rate controls the step size in each update. Proper momentum prevents oscillations, while an appropriate learning rate balances convergence speed 
        and stable model performance."""

# %% [markdown]
# ### Part 2: Optimizer Techniques

# %%
"""5. Explain the concept of Stochastic Gradient Descent (SGD) and its advantages compared to traditional gradient descent. Discuss its limitations ad scenarios where it is most suitable.
Ans: Stochastic Gradient Descent (SGD) is an optimization method that updates model weights using one random training sample at a time instead of the entire dataset. 
        It converges faster, makes efficient use of memory, and escapes local minima better. However, its randomness may cause noisy updates, making it less suitable 
        for smoother loss landscapes or when noise is detrimental.

6. Describe the concept of Adam optimizer and how it combines momentum and adaptive learning rates. Discuss its benefits and potential drawbacks.
Ans: The Adam optimizer combines the benefits of momentum and adaptive learning rates. It calculates individual adaptive learning rates for each parameter based on 
        past gradients and squares of gradients. This helps it converge faster and be more robust to different learning rates. However, it may require tuning and 
        could overshoot the optimal values in some cases.

7. Explain the concept of RMSprop optimizer and how it addresses the challenges of adaptive learning rates. Compare it with Adam and discuss their relative strengths and weaknesses. 
Ans: RMSprop is an optimizer that addresses the challenges of adaptive learning rates by using a moving average of squared gradients. It helps prevent oscillations 
        in training and converges faster. Compared to Adam, RMSprop is simpler and requires less memory, but it may not adapt learning rates as effectively. 
        Adam performs well in many scenarios but might need more tuning."""

# %% [markdown]
# ### Part 3: Applying Optimizers

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization


def model(OPTIMIZER):
    # loading dataset
    (X_train_full, y_train_full), (X_test, y_test) = mnist.load_data()

    # Scale the data between 0 to 1 by dividing it by 255. as its an unsigned data between 0-255 range
    X_valid, X_train = X_train_full[:5000] / 255., X_train_full[5000:] / 255.
    y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

    # scale the test set as well
    X_test = X_test / 255.
    model = tf.keras.models.Sequential()
    model.add(Flatten(input_shape=[28, 28], name="inputLayer"))
    model.add(Dense(300, activation="relu", name="hiddenLayer1"))
    model.add(Dense(100, activation="relu", name="hiddenLayer2"))
    model.add(Dense(10, activation="softmax", name="outputLayer"))

    model.compile(loss='sparse_categorical_crossentropy',
                optimizer=OPTIMIZER,
                metrics=["accuracy"])
    model.fit(X_train, y_train, epochs=25,
                    validation_data=(X_valid, y_valid), batch_size=1000)
    
    return model.history.history['val_accuracy'][-1]

# %%
# 8.Implement SGD, Adam, and RMSprop optimizers in a deep learning model using a framework of your choice. 
#   Train the model on a suitable dataset and compare their impact on model convergence and performance.
score_data = {
    'score_SGD' : model('SGD'),
    'score_Adam' : model('adam'),
    'score_RMSprop' : model('RMSprop')
}
print("\n\n\n")
print(score_data)
# Out:
# Epoch 1/25
# 55/55 [==============================] - 1s 14ms/step - loss: 2.1256 - accuracy: 0.3139 - val_loss: 1.9099 - val_accuracy: 0.5362
# Epoch 2/25
# 55/55 [==============================] - 1s 12ms/step - loss: 1.7215 - accuracy: 0.6241 - val_loss: 1.5169 - val_accuracy: 0.6916
# Epoch 3/25
# 55/55 [==============================] - 1s 17ms/step - loss: 1.3617 - accuracy: 0.7197 - val_loss: 1.1928 - val_accuracy: 0.7566
# Epoch 4/25
# 55/55 [==============================] - 1s 13ms/step - loss: 1.0882 - accuracy: 0.7696 - val_loss: 0.9657 - val_accuracy: 0.7936
# Epoch 5/25
# 55/55 [==============================] - 1s 12ms/step - loss: 0.9026 - accuracy: 0.7992 - val_loss: 0.8152 - val_accuracy: 0.8184
# Epoch 6/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.7781 - accuracy: 0.8199 - val_loss: 0.7130 - val_accuracy: 0.8348
# Epoch 7/25
# 55/55 [==============================] - 1s 19ms/step - loss: 0.6920 - accuracy: 0.8340 - val_loss: 0.6400 - val_accuracy: 0.8500
# Epoch 8/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.6292 - accuracy: 0.8457 - val_loss: 0.5857 - val_accuracy: 0.8594
# Epoch 9/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.5816 - accuracy: 0.8547 - val_loss: 0.5437 - val_accuracy: 0.8678
# Epoch 10/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.5442 - accuracy: 0.8613 - val_loss: 0.5101 - val_accuracy: 0.8748
# Epoch 11/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.5141 - accuracy: 0.8666 - val_loss: 0.4823 - val_accuracy: 0.8786
# Epoch 12/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.4894 - accuracy: 0.8720 - val_loss: 0.4594 - val_accuracy: 0.8828
# Epoch 13/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.4685 - accuracy: 0.8757 - val_loss: 0.4398 - val_accuracy: 0.8852
# Epoch 14/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.4509 - accuracy: 0.8795 - val_loss: 0.4232 - val_accuracy: 0.8896
# Epoch 15/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.4357 - accuracy: 0.8829 - val_loss: 0.4092 - val_accuracy: 0.8932
# Epoch 16/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.4224 - accuracy: 0.8854 - val_loss: 0.3966 - val_accuracy: 0.8956
# Epoch 17/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.4108 - accuracy: 0.8879 - val_loss: 0.3853 - val_accuracy: 0.8976
# Epoch 18/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.4004 - accuracy: 0.8900 - val_loss: 0.3758 - val_accuracy: 0.8996
# Epoch 19/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.3912 - accuracy: 0.8922 - val_loss: 0.3667 - val_accuracy: 0.9028
# Epoch 20/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.3828 - accuracy: 0.8939 - val_loss: 0.3588 - val_accuracy: 0.9048
# Epoch 21/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.3752 - accuracy: 0.8959 - val_loss: 0.3514 - val_accuracy: 0.9056
# Epoch 22/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.3682 - accuracy: 0.8977 - val_loss: 0.3448 - val_accuracy: 0.9080
# Epoch 23/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.3619 - accuracy: 0.8993 - val_loss: 0.3387 - val_accuracy: 0.9090
# Epoch 24/25
# 55/55 [==============================] - 1s 14ms/step - loss: 0.3560 - accuracy: 0.9006 - val_loss: 0.3333 - val_accuracy: 0.9098
# Epoch 25/25
# 55/55 [==============================] - 1s 14ms/step - loss: 0.3504 - accuracy: 0.9023 - val_loss: 0.3284 - val_accuracy: 0.9120
# Epoch 1/25
# 55/55 [==============================] - 2s 20ms/step - loss: 0.6324 - accuracy: 0.8311 - val_loss: 0.2447 - val_accuracy: 0.9312
# Epoch 2/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2157 - accuracy: 0.9375 - val_loss: 0.1687 - val_accuracy: 0.9520
# Epoch 3/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1568 - accuracy: 0.9554 - val_loss: 0.1345 - val_accuracy: 0.9638
# Epoch 4/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1225 - accuracy: 0.9655 - val_loss: 0.1229 - val_accuracy: 0.9668
# Epoch 5/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0999 - accuracy: 0.9709 - val_loss: 0.1020 - val_accuracy: 0.9716
# Epoch 6/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0831 - accuracy: 0.9762 - val_loss: 0.0934 - val_accuracy: 0.9722
# Epoch 7/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0681 - accuracy: 0.9805 - val_loss: 0.0793 - val_accuracy: 0.9770
# Epoch 8/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0570 - accuracy: 0.9837 - val_loss: 0.0804 - val_accuracy: 0.9760
# Epoch 9/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0485 - accuracy: 0.9865 - val_loss: 0.0739 - val_accuracy: 0.9770
# Epoch 10/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0406 - accuracy: 0.9883 - val_loss: 0.0719 - val_accuracy: 0.9762
# Epoch 11/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0350 - accuracy: 0.9909 - val_loss: 0.0690 - val_accuracy: 0.9786
# Epoch 12/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0306 - accuracy: 0.9917 - val_loss: 0.0673 - val_accuracy: 0.9796
# Epoch 13/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0252 - accuracy: 0.9940 - val_loss: 0.0694 - val_accuracy: 0.9786
# Epoch 14/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0210 - accuracy: 0.9954 - val_loss: 0.0658 - val_accuracy: 0.9786
# Epoch 15/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0179 - accuracy: 0.9962 - val_loss: 0.0646 - val_accuracy: 0.9798
# Epoch 16/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0156 - accuracy: 0.9972 - val_loss: 0.0653 - val_accuracy: 0.9808
# Epoch 17/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0131 - accuracy: 0.9977 - val_loss: 0.0658 - val_accuracy: 0.9784
# Epoch 18/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0113 - accuracy: 0.9982 - val_loss: 0.0717 - val_accuracy: 0.9776
# Epoch 19/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0099 - accuracy: 0.9986 - val_loss: 0.0645 - val_accuracy: 0.9788
# Epoch 20/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0078 - accuracy: 0.9991 - val_loss: 0.0660 - val_accuracy: 0.9786
# Epoch 21/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0068 - accuracy: 0.9994 - val_loss: 0.0658 - val_accuracy: 0.9806
# Epoch 22/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0058 - accuracy: 0.9995 - val_loss: 0.0661 - val_accuracy: 0.9802
# Epoch 23/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0050 - accuracy: 0.9997 - val_loss: 0.0701 - val_accuracy: 0.9810
# Epoch 24/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0042 - accuracy: 0.9997 - val_loss: 0.0665 - val_accuracy: 0.9800
# Epoch 25/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0037 - accuracy: 0.9998 - val_loss: 0.0693 - val_accuracy: 0.9810
# Epoch 1/25
# 55/55 [==============================] - 3s 19ms/step - loss: 0.6436 - accuracy: 0.8164 - val_loss: 0.3463 - val_accuracy: 0.8916
# Epoch 2/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2714 - accuracy: 0.9207 - val_loss: 0.2031 - val_accuracy: 0.9444
# Epoch 3/25
# 55/55 [==============================] - 1s 20ms/step - loss: 0.2009 - accuracy: 0.9410 - val_loss: 0.1618 - val_accuracy: 0.9550
# Epoch 4/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1567 - accuracy: 0.9541 - val_loss: 0.1308 - val_accuracy: 0.9634
# Epoch 5/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1269 - accuracy: 0.9626 - val_loss: 0.1076 - val_accuracy: 0.9694
# Epoch 6/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.1052 - accuracy: 0.9694 - val_loss: 0.1000 - val_accuracy: 0.9732
# Epoch 7/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0875 - accuracy: 0.9745 - val_loss: 0.0894 - val_accuracy: 0.9734
# Epoch 8/25
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0761 - accuracy: 0.9775 - val_loss: 0.0902 - val_accuracy: 0.9730
# Epoch 9/25
# 55/55 [==============================] - 1s 22ms/step - loss: 0.0651 - accuracy: 0.9807 - val_loss: 0.0761 - val_accuracy: 0.9758
# Epoch 10/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0568 - accuracy: 0.9831 - val_loss: 0.0724 - val_accuracy: 0.9776
# Epoch 11/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0500 - accuracy: 0.9852 - val_loss: 0.0712 - val_accuracy: 0.9792
# Epoch 12/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0435 - accuracy: 0.9873 - val_loss: 0.0655 - val_accuracy: 0.9808
# Epoch 13/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0370 - accuracy: 0.9892 - val_loss: 0.0720 - val_accuracy: 0.9778
# Epoch 14/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0323 - accuracy: 0.9911 - val_loss: 0.0728 - val_accuracy: 0.9796
# Epoch 15/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0277 - accuracy: 0.9924 - val_loss: 0.0672 - val_accuracy: 0.9804
# Epoch 16/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0255 - accuracy: 0.9927 - val_loss: 0.0615 - val_accuracy: 0.9814
# Epoch 17/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0230 - accuracy: 0.9939 - val_loss: 0.0610 - val_accuracy: 0.9808
# Epoch 18/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0185 - accuracy: 0.9952 - val_loss: 0.0589 - val_accuracy: 0.9834
# Epoch 19/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0170 - accuracy: 0.9961 - val_loss: 0.0749 - val_accuracy: 0.9792
# Epoch 20/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0148 - accuracy: 0.9967 - val_loss: 0.0568 - val_accuracy: 0.9832
# Epoch 21/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0154 - accuracy: 0.9960 - val_loss: 0.0599 - val_accuracy: 0.9826
# Epoch 22/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0102 - accuracy: 0.9979 - val_loss: 0.0625 - val_accuracy: 0.9828
# Epoch 23/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0099 - accuracy: 0.9978 - val_loss: 0.0593 - val_accuracy: 0.9840
# Epoch 24/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0083 - accuracy: 0.9982 - val_loss: 0.0709 - val_accuracy: 0.9804
# Epoch 25/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0073 - accuracy: 0.9985 - val_loss: 0.0600 - val_accuracy: 0.9844
#
#
#
#
# {'score_SGD': 0.9120000004768372, 'score_Adam': 0.9810000061988831, 'score_RMSprop': 0.9843999743461609}

# %%
"""9. Discuss the considerations and tradeoffs when choosing the appropriate optimizer for a given neural network architecture and task. Consider factors such as convergence speed, stability and generalization performance. 
    Ans: Choosing the right optimizer for a neural network involves tradeoffs among convergence speed, stability, and generalization performance. Gradient Descent is simple but slow. 
            Stochastic Gradient Descent (SGD) converges faster but may be unstable. 
            Adam optimizer balances speed and stability with adaptive learning rates. 
            RMSprop is stable but might converge slower. 
        The choice depends on the specific task, architecture, and data. Experimentation and tuning are essential to find the best optimizer for optimal training performance."""
